# %% [markdown]
# <a href="https://colab.research.google.com/github/dalfonsoa/Inteligencai_Artificial/blob/main/Tarea1_Parte2_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

class Estadísticas:
    def __init__(self, filename):
        self.data = pd.read_csv(filename)

    def calculate_statistics(self, variable_name):
        if variable_name not in self.data.columns:
            return "Variable no encontrada."
        variable_data = self.data[variable_name]
        statistics = {
            "Media": variable_data.mean(),
            "Mediana": variable_data.median(),
            "Desviación Estándar": variable_data.std(),
            "Percentil 25": variable_data.quantile(0.25),
            "Percentil 50": variable_data.quantile(0.5),
            "Percentil 75": variable_data.quantile(0.75),
        }
        return statistics

    def get_variable_names(self):
        return list(self.data.columns)

    def plot_histogram(self, variable_name):
        if variable_name not in self.data.columns:
            return "Variable no encontrada."
        variable_data = self.data[variable_name]
        plt.hist(variable_data, bins=20, edgecolor='k')
        plt.xlabel(variable_name)
        plt.ylabel("Frecuencia")
        plt.title(f"Histograma de {variable_name}")
        plt.show()

# %%
iris_stats = DescriptiveStatistics("iris.csv")
variable_names = iris_stats.get_variable_names()
print("Variables disponibles:", variable_names)

# Cambia el nombre de la variable según tu elección
variable_name = "sepallength"
statistics = iris_stats.calculate_statistics(variable_name)
print(f"Estadísticas para {variable_name}:")
for stat, value in statistics.items():
    print(f"{stat}: {value}")

# Dibuja un histograma para la variable seleccionada
iris_stats.plot_histogram(variable_name)
# Out:
# Variables disponibles: ['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class']
# Estadísticas para sepallength:
# Media: 5.843333333333334
# Mediana: 5.8
# Desviación Estándar: 0.828066127977863
# Percentil 25: 5.1
# Percentil 50: 5.8
# Percentil 75: 6.4

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
